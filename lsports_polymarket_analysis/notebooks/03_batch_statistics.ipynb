# %% [markdown]
# # 03 · 批量赛事统计
# 读取 `scripts/batch_event_analysis.py` 产出的统计表并探索。

# %%
import pandas as pd
match = pd.read_csv('../outputs/tables/match_summary.csv')
goals = pd.read_csv('../outputs/tables/goal_event_summary.csv')
latency = pd.read_csv('../outputs/tables/latency_summary.csv')
match.describe(include='all')

# %%
match.groupby('event_date')['n_goals'].agg(['count','mean','sum'])

# %%
latency['median_event_gap_sec'].describe()  # LSports 更新时间分辨率
